# %% [markdown]
# # Расчеты для мамы

# %% [markdown]
# 1. Шпагаты
# 2. Поочередные махи ногами
# 3. Базовые движения рук
# 4. Блок обязательных «чир прыжков»
# 5. Блок обязательных «лип прыжков»
# 6. Разнообразные пируэты различной сложности
# 7. Акробатические элементы
# 8. Контроль точности и координации движений
# 9. Контроль чувства ритма
# 10. Контроль за командной синхронностью

# %% [markdown]
# ## 1 Этат теста

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame(np.array([[0, 2, 14, 10 ,14],
                             [0, 2, 8, 14 ,16],
                             [4, 6, 9, 11 ,10],
                             [12, 15, 4, 5 ,4],
                             [2, 10, 11, 9 ,8],
                             [6, 8, 14, 5 ,7],
                             [7, 5, 9, 9 ,10],
                             [10, 9, 9, 5 ,7],
                             [0, 6, 10, 12 ,12],
                             [7, 8, 11, 4 ,10]]),columns=[1, 2, 3, 4, 5],
                              index=['Шпагаты',
                                     'Поочередные махи ногами',
                                     'Базовые движения рук',
                                     'Блок обязательных «чир прыжков»',
                                     'Блок обязательных «лип прыжков»',
                                     'Разнообразные пируэты различной сложности',
                                     'Акробатические элементы',
                                     'Контроль точности и координации движений',
                                     'Контроль чувства ритма',
                                     'Контроль за командной синхронностью'])

# %%
df1['X'] = (df1[1]*1 +df1[2]*2 + df1[3]*3+ df1[4]*4+df1[5]*5)/(df1[1] +df1[2] + df1[3]+ df1[4]+df1[5])

# %%
df1
# Out:
#                                             1   2   3   4   5      X
# Шпагаты                                     0   2  14  10  14  3.900
# Поочередные махи ногами                     0   2   8  14  16  4.100
# Базовые движения рук                        4   6   9  11  10  3.425
# Блок обязательных «чир прыжков»            12  15   4   5   4  2.350
# Блок обязательных «лип прыжков»             2  10  11   9   8  3.275
# Разнообразные пируэты различной сложности   6   8  14   5   7  2.975
# Акробатические элементы                     7   5   9   9  10  3.250
# Контроль точности и координации движений   10   9   9   5   7  2.750
# Контроль чувства ритма                      0   6  10  12  12  3.750
# Контроль за командной синхронностью         7   8  11   4  10  3.050

# %% [markdown]
# #### Вычисление дисперсии оценок студентов D

# %% [markdown]
# Сумма квадратов отклонений деленное на число студентов

# %%
df1['D'] = ((df1['X']-df1[1])**2 + (df1['X']-df1[2])**2 + (df1['X']-df1[3])**2 + (df1['X']-df1[4])**2 + (df1['X']-df1[5])**2)/40

# %%
df1
# Out:
#                                             1   2   3   4   5      X         D
# Шпагаты                                     0   2  14  10  14  3.900  6.501250
# Поочередные махи ногами                     0   2   8  14  16  4.100  6.901250
# Базовые движения рук                        4   6   9  11  10  3.425  3.466328
# Блок обязательных «чир прыжков»            12  15   4   5   4  2.350  6.640313
# Блок обязательных «лип прыжков»             2  10  11   9   8  3.275  4.040703
# Разнообразные пируэты различной сложности   6   8  14   5   7  2.975  4.406328
# Акробатические элементы                     7   5   9   9  10  3.250  3.220312
# Контроль точности и координации движений   10   9   9   5   7  2.750  3.845312
# Контроль чувства ритма                      0   6  10  12  12  3.750  4.857812
# Контроль за командной синхронностью         7   8  11   4  10  3.050  3.812813

# %% [markdown]
# #### Вычисления стандартного отклонения оценок студентов σ (это конень от D)

# %%
df1['σ'] = df1['D']**0.5

# %%
df1
# Out:
#                                             1   2   3   4   5      X  \
# Шпагаты                                     0   2  14  10  14  3.900
# Поочередные махи ногами                     0   2   8  14  16  4.100
# Базовые движения рук                        4   6   9  11  10  3.425
# Блок обязательных «чир прыжков»            12  15   4   5   4  2.350
# Блок обязательных «лип прыжков»             2  10  11   9   8  3.275
# Разнообразные пируэты различной сложности   6   8  14   5   7  2.975
# Акробатические элементы                     7   5   9   9  10  3.250
# Контроль точности и координации движений   10   9   9   5   7  2.750
# Контроль чувства ритма                      0   6  10  12  12  3.750
# Контроль за командной синхронностью         7   8  11   4  10  3.050
#
#                                                   D         σ
# Шпагаты                                    6.501250  2.549755
# Поочередные махи ногами                    6.901250  2.627023
# Базовые движения рук                       3.466328  1.861808
# Блок обязательных «чир прыжков»            6.640313  2.576880
# Блок обязательных «лип прыжков»            4.040703  2.010150
# Разнообразные пируэты различной сложности  4.406328  2.099126
# Акробатические элементы                    3.220312  1.794523
# Контроль точности и координации движений   3.845312  1.960947
# Контроль чувства ритма                     4.857812  2.204045
# Контроль за командной синхронностью        3.812813  1.952642

# %% [markdown]
# #### Вычисления m

# %%
df1['m'] = df1['σ']/40**0.5

# %%
df1
# Out:
#                                             1   2   3   4   5      X  \
# Шпагаты                                     0   2  14  10  14  3.900
# Поочередные махи ногами                     0   2   8  14  16  4.100
# Базовые движения рук                        4   6   9  11  10  3.425
# Блок обязательных «чир прыжков»            12  15   4   5   4  2.350
# Блок обязательных «лип прыжков»             2  10  11   9   8  3.275
# Разнообразные пируэты различной сложности   6   8  14   5   7  2.975
# Акробатические элементы                     7   5   9   9  10  3.250
# Контроль точности и координации движений   10   9   9   5   7  2.750
# Контроль чувства ритма                      0   6  10  12  12  3.750
# Контроль за командной синхронностью         7   8  11   4  10  3.050
#
#                                                   D         σ         m
# Шпагаты                                    6.501250  2.549755  0.403152
# Поочередные махи ногами                    6.901250  2.627023  0.415369
# Базовые движения рук                       3.466328  1.861808  0.294378
# Блок обязательных «чир прыжков»            6.640313  2.576880  0.407441
# Блок обязательных «лип прыжков»            4.040703  2.010150  0.317833
# Разнообразные пируэты различной сложности  4.406328  2.099126  0.331901
# Акробатические элементы                    3.220312  1.794523  0.283739
# Контроль точности и координации движений   3.845312  1.960947  0.310053
# Контроль чувства ритма                     4.857812  2.204045  0.348490
# Контроль за командной синхронностью        3.812813  1.952642  0.308740

# %% [markdown]
# ## 2 Этат теста

# %%
df2 = pd.DataFrame(np.array([[0, 0, 6, 10 ,24],
                             [0, 0, 6, 6 ,28],
                             [0, 0, 4, 16 ,20],
                             [0, 1, 9, 8 ,12],
                             [0, 0, 8, 17 ,15],
                             [0, 2, 15, 10 ,13],
                             [0, 0, 13, 9 ,18],
                             [0, 0, 12, 10 ,18],
                             [0, 0, 11, 9 ,20],
                             [0, 2, 11, 13 ,14]]),columns=[1, 2, 3, 4, 5],
                              index=['Шпагаты',
                                     'Поочередные махи ногами',
                                     'Базовые движения рук',
                                     'Блок обязательных «чир прыжков»',
                                     'Блок обязательных «лип прыжков»',
                                     'Разнообразные пируэты различной сложности',
                                     'Акробатические элементы',
                                     'Контроль точности и координации движений',
                                     'Контроль чувства ритма',
                                     'Контроль за командной синхронностью'])

# %%
df2
# Out:
#                                            1  2   3   4   5
# Шпагаты                                    0  0   6  10  24
# Поочередные махи ногами                    0  0   6   6  28
# Базовые движения рук                       0  0   4  16  20
# Блок обязательных «чир прыжков»            0  1   9   8  12
# Блок обязательных «лип прыжков»            0  0   8  17  15
# Разнообразные пируэты различной сложности  0  2  15  10  13
# Акробатические элементы                    0  0  13   9  18
# Контроль точности и координации движений   0  0  12  10  18
# Контроль чувства ритма                     0  0  11   9  20
# Контроль за командной синхронностью        0  2  11  13  14

# %% [markdown]
# Проводим аналогичние расчеты

# %%
df2['X'] = (df2[1]*1 +df2[2]*2 + df2[3]*3+ df2[4]*4+df2[5]*5)/(df2[1] +df2[2] + df2[3]+ df2[4]+df2[5])
df2['D'] = ((df2['X']-df2[1])**2 + (df2['X']-df2[2])**2 + (df2['X']-df2[3])**2 + (df2['X']-df2[4])**2 + (df2['X']-df2[5])**2)/40
df2['σ'] = df2['D']**0.5
df2['m'] = df2['σ']/40**0.5

# %%
df2
# Out:
#                                            1  2   3   4   5         X  \
# Шпагаты                                    0  0   6  10  24  4.450000
# Поочередные махи ногами                    0  0   6   6  28  4.550000
# Базовые движения рук                       0  0   4  16  20  4.400000
# Блок обязательных «чир прыжков»            0  1   9   8  12  4.033333
# Блок обязательных «лип прыжков»            0  0   8  17  15  4.175000
# Разнообразные пируэты различной сложности  0  2  15  10  13  3.850000
# Акробатические элементы                    0  0  13   9  18  4.125000
# Контроль точности и координации движений   0  0  12  10  18  4.150000
# Контроль чувства ритма                     0  0  11   9  20  4.225000
# Контроль за командной синхронностью        0  2  11  13  14  3.975000
#
#                                                    D         σ         m
# Шпагаты                                    11.375313  3.372731  0.533276
# Поочередные махи ногами                    14.887812  3.858473  0.610078
# Базовые движения рук                       10.420000  3.228002  0.510392
# Блок обязательных «чир прыжков»             3.233472  1.798186  0.284318
# Блок обязательных «лип прыжков»             8.278828  2.877295  0.454940
# Разнообразные пируэты различной сложности   6.602813  2.569594  0.406288
# Акробатические элементы                     8.226953  2.868267  0.453513
# Контроль точности и координации движений    8.052812  2.837748  0.448687
# Контроль чувства ритма                      8.831328  2.971755  0.469876
# Контроль за командной синхронностью         6.275078  2.505011  0.396077

# %% [markdown]
# Расчет t-критерия оченки

# %%
P = (df1['X']-df2['X'])/((df1['m']**2 + df2['m']**2)**0.5)

# %%
P
# Out:
# Шпагаты                                     -0.822717
# Поочередные махи ногами                     -0.609710
# Базовые движения рук                        -1.654782
# Блок обязательных «чир прыжков»             -3.388116
# Блок обязательных «лип прыжков»             -1.621718
# Разнообразные пируэты различной сложности   -1.667867
# Акробатические элементы                     -1.635638
# Контроль точности и координации движений    -2.566958
# Контроль чувства ритма                      -0.811962
# Контроль за командной синхронностью         -1.841923
# dtype: float64
